# %%
import os
import pandas as pd

root = '/workspace/data/도서대출자료'
month = '1월'
book_file_name = '부산광역시립서동도서관 장서 대출목록 (2024년 01월).xlsx'

df_book = pd.read_excel(os.path.join(root, month, book_file_name))
df_book = df_book.loc[:, ['도서명', '저자', '출판사', '권', '도서권수', '대출건수', 'ISBN', '등록일자']]
display(df_book)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                                       도서명  \
# 0                         요괴어사:역사 판타지 소설.
# 1                   내가 한 말을 내가 오해하지 않기로 함
# 2       남에게 보여주려고 인생을 낭비하지 마라 - 쇼펜하우어 소품집
# 3                                생일 축하합니다
# 4       마흔에 읽는 쇼펜하우어 - 마음의 위기를 다스리는 철학 수업
# ...                                   ...
# 203930                       워드프로세서 1급 실기
# 203931                         에우로페와 카드모스
# 203932       (The)secret birthday message
# 203933                        미드 자막없이 즐겨라
# 203934                            숨쉬는 중국어
#
#                                                        저자             출판사  \
# 0                                              설민석,원더스 지음            단꿈아이
# 1                                               문상훈 (지은이)            위너스북
# 2                             아르투어 쇼펜하우어 (지은이), 박제헌 (옮긴이)     페이지2(page2)
# 3                                               최지웅 (지은이)  프로파간다 시네마 그래픽스
# 4                                               강용수 (지은이)         유노콘텐츠그룹
# ...                                                   ...             ...
# 203930                                          길벗 R&D 지음              길벗
# 203931  original story by Thomas Bulfinch;rewritten by...      HAPPYHOUSE
# 203932                                      by Eric Carle   HarperCollins
# 203933                                             안병규 지음         이퍼블릭로그인
# 203934                                       이명순 저;이일선 그림           송산출판사
#
#           권  도서권수  대출건수           ISBN        등록일자
# 0         2     1     0  9791193031360  2024-01-25
# 1       NaN     1     0  9791189352745  2024-01-25
# 2       NaN     1     0  9791169850445  2024-01-25
# 3       NaN     1     0  9791198443113  2024-01-25
# 4       NaN     1     0  9791192300818  2024-01-25
# ...     ...   ...   ...            ...         ...
# 203930  NaN     1     0  9788975606908  2004-06-08
# 203931    5     1     0  9788956555799  2004-06-08
# 203932  NaN     1     0  9780064430999  2004-06-08
# 203933  NaN     1     0  9788973319558  2004-06-08
# 203934    1     1     0  9788977801103  2004-06-08
#
# [203935 rows x 8 columns]

# %% [markdown]
# ## 데이터 결측치 개수

# %%
df_book.isnull().sum()
# Out:
# 도서명          0
# 저자          19
# 출판사       2249
# 권       178631
# 도서권수         0
# 대출건수         0
# ISBN         0
# 등록일자         0
# dtype: int64
