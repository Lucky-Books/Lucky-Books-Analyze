# %%
import os
import pandas as pd

root = '/workspace/data/도서대출자료'
month = '1월'
book_file_name = '부산광역시립시민도서관 장서 대출목록 (2024년 01월).xlsx'

df_book = pd.read_excel(os.path.join(root, month, book_file_name))
df_book = df_book.loc[:, ['도서명', '저자', '출판사', '권', '도서권수', '대출건수', 'ISBN', '등록일자']]
display(df_book)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                                                      도서명  \
# 0                                            나랑 같이 축구할래?
# 1                                               축구 잘하는 법
# 2                                         축구 잘하는 50가지 비밀
# 3                                        (흔한남매)수수께끼 어드벤처
# 4                                               칵테일과 레코드
# ...                                                  ...
# 665491  (Live abc) 생활영어그림사전대백과=Life picture encyclopedia
# 665492                                      (청소년을 위한)장길산
# 665493                                      (청소년을 위한)장길산
# 665494                                      (청소년을 위한)장길산
# 665495                                 창문너머 또 하나의 창이 열린다
#
#                                                        저자                 출판사  \
# 0                                                안재선 글·그림               엔씨소프트
# 1       호사카 노부유키 지음;후타미 유지,후치모토 토모노부 [공]사진;Gahag 그림;김연...  Gri.joa FC(그리조아FC)
# 2       길 하비,조나단 셰이크 밀러 외 지음;크리스 콜,숀 보터릴 [공]사진;밥 본드 일러...        라이카미(부즈펌어린이)
# 3                                  흔한남매 원작;노지영 글;도니패밀리 그림             미래엔아이세움
# 4                 안드레 달링턴,테나야 달링턴 [공]지음;제이슨 바니 사진;권루시안 옮김         진선북스(진선출판사)
# ...                                                   ...                 ...
# 665491                                       라이브앤씨씨 편집부 편              라이브ABC
# 665492                                                황석영              책이있는마을
# 665493                                                황석영              책이있는마을
# 665494                                                황석영              책이있는마을
# 665495                                             정미셸 지음               베드로서원
#
#           권  도서권수  대출건수           ISBN        등록일자
# 0       NaN     1     0  9791165515935  2024-01-30
# 1       NaN     1     0  9791189460013  2024-01-30
# 2       NaN     1     0  9791190808729  2024-01-30
# 3         4     1     0  9791168417656  2024-01-30
# 4       NaN     1     0  9791193003299  2024-01-30
# ...     ...   ...   ...            ...         ...
# 665491    2     3     0  9788991578036  2004-09-08
# 665492   10     1     2  9788956390475  2004-07-29
# 665493    9     1     2  9788956390468  2004-07-29
# 665494    8     1     2  9788956390451  2004-07-29
# 665495  NaN     1     1  9788974191542  1970-01-01
#
# [665496 rows x 8 columns]

# %% [markdown]
# ## 데이터 결측치 개수

# %%
df_book.isnull().sum()
# Out:
# 도서명          1
# 저자         471
# 출판사      20837
# 권       554889
# 도서권수         0
# 대출건수         0
# ISBN         0
# 등록일자         0
# dtype: int64
