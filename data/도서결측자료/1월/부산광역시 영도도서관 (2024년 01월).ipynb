# %%
import os
import pandas as pd

root = '/workspace/data/도서대출자료'
month = '1월'
book_file_name = '부산광역시 영도도서관 장서 대출목록 (2024년 01월).xlsx'

df_book = pd.read_excel(os.path.join(root, month, book_file_name))
df_book = df_book.loc[:, ['도서명', '저자', '출판사', '권', '도서권수', '대출건수', 'ISBN', '등록일자']]
display(df_book)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                                                    도서명  \
# 0                    망그러진 만화2:망그러진 곰과 햄터의 데굴데굴 유쾌한 날들!
# 1       진짜 식사1:몸에서 질병을 몰아내고, 암세포를 파괴하고, 다이어트에 좋은 최강 음식
# 2                                          전사들 얼티밋 가이드
# 3                                    Go Go 카카오프렌즈 자연탐사
# 4                                             별을 쫓는 자들
# ...                                                ...
# 215835                      작은 너의 몸짓 하나까지도 늘 처음처럼 바라볼게
# 215836                                 성교육/성상담의 이론과 실제
# 215837                                     한국분 한국인 한국놈
# 215838                                         잃어버린 세계
# 215839                                            깊은 강
#
#                                   저자     출판사    권  도서권수  대출건수           ISBN  \
# 0                            유랑 글·그림    좋은생각  NaN     1     0  9791193300077
# 1                       한의학박사 김순렬 지음    리더북스  NaN     1     0  9791193555002
# 2       에린 헌터 지음;웨인 매클로플린 그림 ;서현정 옮김   가람어린이  NaN     1     0  9791165182793
# 3                       조주희 글;김정한 그림     아울북    6     1     0  9791171173235
# 4                    에린 헌터 지음;김진주 옮김   가람어린이    1     1     0  9791165182861
# ...                              ...     ...  ...   ...   ...            ...
# 215835                         지예 지음   오늘의 책  NaN     1     1  9788977180970
# 215836                        김상원 편저  교육아카데미  NaN     1     1  9788987252155
# 215837                         백현락 저      도솔  NaN     1     1  9788972200611
# 215838                   마이클 크라이튼 지음     김영사    2     2     1  9788934902669
# 215839                      엔도 슈사쿠 저     고려원  NaN     2     1  9788912111601
#
#               등록일자
# 0       2024-01-26
# 1       2024-01-26
# 2       2024-01-26
# 3       2024-01-26
# 4       2024-01-26
# ...            ...
# 215835  1970-01-01
# 215836  1970-01-01
# 215837  1970-01-01
# 215838  1970-01-01
# 215839  1970-01-01
#
# [215840 rows x 8 columns]

# %% [markdown]
# ## 데이터 결측치 개수

# %%
df_book.isnull().sum()
# Out:
# 도서명          1
# 저자          42
# 출판사       2046
# 권       164032
# 도서권수         0
# 대출건수         0
# ISBN         0
# 등록일자         0
# dtype: int64
