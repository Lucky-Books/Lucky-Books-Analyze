# %%
import os
import pandas as pd

root = '/workspace/data/도서대출자료'
month = '1월'
book_file_name = '부산광역시 수영구도서관 장서 대출목록 (2024년 01월).xlsx'

df_book = pd.read_excel(os.path.join(root, month, book_file_name))
df_book = df_book.loc[:, ['도서명', '저자', '출판사', '권', '도서권수', '대출건수', 'ISBN', '등록일자']]
display(df_book)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                           도서명                            저자      출판사    권  \
# 0            (흔한남매)수수께끼 어드벤처.        흔한남매 원작;노지영 글;도니패밀리 그림  미래엔아이세움    4
# 1                 다 해결 고양이 탐정                 정유리 지음;홍그림 그림   잇츠북어린이  NaN
# 2                      어린이 면허     마르탱 파주 지음;로낭 바델 그림;양진희 옮김   우리들의행성  NaN
# 3                     오소리의 시간  그로 달레 글;카이아 달레 뉘후스 그림;공경희 옮김    길벗어린이  NaN
# 4                마음에도 문이 있어요?  에즈기 베르크 글;오즈누르 손메즈 그림;최진희 옮김    라이브리안  NaN
# ...                       ...                           ...      ...  ...
# 180010                   장미정원              아일린 굿지 지음;박길부 옮김      늘푸른    2
# 180011                   장미정원              아일린 굿지 지음;박길부 옮김      늘푸른    1
# 180012                코끼리와 벼룩               찰스 핸디 지음;이종인 옮김   생각의 나무  NaN
# 180013                 곶감과 수필                        윤오영 지음      태학사  NaN
# 180014  살아 남은 자의 슬픔:박일문 장편소설.                        박일문 지음      民音社  NaN
#
#         도서권수  대출건수           ISBN        등록일자
# 0          1     0  9791168417656  2024-01-31
# 1          1     0  9791192182841  2024-01-31
# 2          1     0  9791197835131  2024-01-31
# 3          1     0  9788955826760  2024-01-31
# 4          1     0  9791196816025  2024-01-31
# ...      ...   ...            ...         ...
# 180010     1     1  9788973600274  1970-01-01
# 180011     1     2  9788973600274  1970-01-01
# 180012     1     1  9788984980860  1970-01-01
# 180013     1     1  9788976265357  1970-01-01
# 180014     2     1  9788937400377  1970-01-01
#
# [180015 rows x 8 columns]

# %% [markdown]
# ## 데이터 결측치 개수

# %%
df_book.isnull().sum()
# Out:
# 도서명          0
# 저자         228
# 출판사       2760
# 권       136544
# 도서권수         0
# 대출건수         0
# ISBN         0
# 등록일자         0
# dtype: int64
